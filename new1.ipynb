# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df= pd.read_csv('final_data.csv')
df.columns
# Out:
# Index(['CITY', 'DISTRICT', 'ADDRESS', 'TALUK', 'PINCODE', 'GENDER',
#        'FAMILY_INCOME', 'CET_RANK', 'KEA_CLAIM_CAT', 'ADMIN MODE', 'AdminYear',
#        'SSLCTOTMARKS', 'PUCTOTMARKS', 'PUC_INSTITUTE', 'puc_yr_pass',
#        'sslc_yr_pass', 'PCM_total', 'PCM %', 'STATE', 'Religion/ Caste'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CITY             450 non-null    object
#  1   DISTRICT         450 non-null    object
#  2   ADDRESS          450 non-null    object
#  3   TALUK            450 non-null    object
#  4   PINCODE          450 non-null    int64
#  5   GENDER           450 non-null    object
#  6   FAMILY_INCOME    450 non-null    int64
#  7   CET_RANK         362 non-null    float64
#  8   KEA_CLAIM_CAT    450 non-null    object
#  9   ADMIN MODE       445 non-null    object
#  10  AdminYear        450 non-null    int64
#  11  SSLCTOTMARKS     450 non-null    float64
#  12  PUCTOTMARKS      450 non-null    float64
#  13  PUC_INSTITUTE    450 non-null    object
#  14  puc_yr_pass      437 non-null    float64
#  15  sslc_yr_pass     450 non-null    int64
# ...

# %%
years =list(df['AdminYear'].unique())

# %%
len(list(df['PUC_INSTITUTE'].unique()))
# Out:
# 186

# %%
years
# Out:
# [2019, 2020, 2021, 2022, 2023]

# %%
categorical_cols = ['DISTRICT','TALUK','CITY']
for col in categorical_cols:
    for year in years:
        plt.figure(figsize=(10, 6))  # Larger figure size for better visibility
        sns.countplot(data=df[df['AdminYear'] == year], x=col, palette='viridis')  # Use a color palette for better differentiation
        plt.title(f'Countplot of {col} in {year}', fontsize=16)  # Larger title font size
        plt.xlabel(col, fontsize=14)  # Larger x-axis label font size
        plt.ylabel('Count', fontsize=14)  # Larger y-axis label font size
        plt.xticks(rotation=45, ha='right', fontsize=12)  # Rotate x-axis labels for better readability
        plt.yticks(fontsize=12)  # Font size of y-axis ticks
        plt.tight_layout()  # Adjust layout to prevent clipping of labels
        plt.show()
# Out:
# /tmp/ipykernel_846206/608545053.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df[df['AdminYear'] == year], x=col, palette='viridis')  # Use a color palette for better differentiation
# /tmp/ipykernel_846206/608545053.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df[df['AdminYear'] == year], x=col, palette='viridis')  # Use a color palette for better differentiation
# /tmp/ipykernel_846206/608545053.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Example data setup (replace with your actual data)
years = list(df['AdminYear'].unique())
years.pop()  # Remove the last year if it's not needed
categorical_cols = ['TALUK']

# Loop through each categorical column and each year
for col in categorical_cols:
    for year in years:
        plt.figure(figsize=(6, 6))  # Square figure for pie chart
        
        # Filter data for the specific year and column
        data_year = df[df['AdminYear'] == year][col].value_counts()
        
        # Plotting the pie chart with percentage and counts
        patches, autotexts = plt.pie(data_year, labels=None, 
                                           startangle=-30, 
                                           colors=sns.color_palette('viridis', len(data_year)), 
                                           wedgeprops={'edgecolor': 'black'})
        
        # Customize autopct label properties
        for autotext in autotexts:
            autotext.set_fontsize(15)  # Set font size
            autotext.set_color('white')  # Set text color to white for better contrast
        
        # Set equal aspect ratio to ensure pie is drawn as a circle
        plt.axis('equal')
        
        # Add legend with category names outside the pie chart
        plt.legend(data_year.index, loc='upper right', fontsize=10, title=f'{col} Categories')
        
       # Annotate each slice with percentages along the circumference
        for i, (patch, label) in enumerate(zip(patches, data_year.index)):
            ang = (patch.theta2 + patch.theta1) / 2.  # Find the middle of the wedge
            x = 1.1 * np.cos(np.deg2rad(ang))  # Adjust x position slightly outside the pie
            y = 1.1 * np.sin(np.deg2rad(ang))  # Adjust y position slightly outside the pie
            plt.text(x, y, f'{data_year.iloc[i]/data_year.sum()*100:.1f}%', fontsize=10, ha='center', va='center')
                
        plt.title(f'Pie Chart of {col} in {year}', fontsize=16)  # Larger title font size
        plt.tight_layout()  # Adjust layout to prevent clipping of labels
        plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Define categorical columns (if necessary)
categorical_cols = ['DISTRICT']

# Combine all data for the plot
combined_data = df[df['AdminYear'].isin(years)]
# Set the visual aesthetics with Seaborn
sns.set_style('whitegrid')
custom_colors = ['#e41a1c', '#377eb8', '#4daf4a','#984ea3','#ff7f00']
plt.figure(figsize=(16, 10))  # Larger figure size for better visibility and spacing

# Create the countplot with Seaborn
sns.countplot(data=combined_data, x='DISTRICT', hue='AdminYear', palette=custom_colors, edgecolor='black')  # Use edgecolor for better separation
plt.title('Count of Districts by Year', fontsize=18, fontweight='bold')  # Larger and bold title
plt.xlabel('District', fontsize=14, fontweight='bold')  # Larger and bold x-axis label
plt.ylabel('Count', fontsize=14, fontweight='bold')  # Larger and bold y-axis label
plt.xticks(rotation=45, ha='right', fontsize=12)  # Rotate x-axis labels for better readability
plt.yticks(fontsize=12)  # Font size of y-axis ticks
plt.legend(title='years', fontsize=12, title_fontsize='14', loc='upper right')  # Add legend for years with larger font sizes

# Add grid lines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()  # Adjust layout to prevent clipping of labels and elements
plt.show()
# Out:
# /tmp/ipykernel_846206/765267433.py:16: UserWarning: The palette list has more values (5) than needed (4), which may not be intended.
#   sns.countplot(data=combined_data, x='DISTRICT', hue='AdminYear', palette=custom_colors, edgecolor='black')  # Use edgecolor for better separation

# %%
categorical_cols = ['PUC_INSTITUTE']
for col in categorical_cols:
    for year in years:
        plt.figure(figsize=(12, 8))
        sns.countplot(data=df[df['AdminYear'] == year], y='PUC_INSTITUTE', palette='viridis', order=df[df['AdminYear'] == year]['PUC_INSTITUTE'].value_counts().index)
        plt.title(f'Countplot of PUC_INSTITUTE in {year}', fontsize=16)
        plt.xlabel('Count', fontsize=14)
        plt.ylabel('PUC_INSTITUTE', fontsize=14)
        plt.xticks(fontsize=12)
        plt.yticks(fontsize=12)
        plt.tight_layout()
        plt.show()
# Out:
# /tmp/ipykernel_846206/2678702067.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df[df['AdminYear'] == year], y='PUC_INSTITUTE', palette='viridis', order=df[df['AdminYear'] == year]['PUC_INSTITUTE'].value_counts().index)
# /tmp/ipykernel_846206/2678702067.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df[df['AdminYear'] == year], y='PUC_INSTITUTE', palette='viridis', order=df[df['AdminYear'] == year]['PUC_INSTITUTE'].value_counts().index)
# /tmp/ipykernel_846206/2678702067.py:5: FutureWarning:
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from seaborn import clustermap

# Create a pivot table for the heatmap
heatmap_data = df.pivot_table(index='PUC_INSTITUTE', columns='AdminYear', aggfunc='size', fill_value=0)

# Plot the heatmap with clustering
plt.figure(figsize=(14, 10))
cluster_map = sns.clustermap(
    heatmap_data,
    cmap='mako',  # Use a different color map for better visual appeal
    annot=True,
    fmt='d',
    linewidths=.5,
    figsize=(14, 10),
    cbar_pos=(0.02, 0.8, 0.03, 0.18),  # Position the color bar
    dendrogram_ratio=(.1, .2),  # Ratio of dendrograms
    col_cluster=True,  # Enable clustering for columns
    row_cluster=True  # Enable clustering for rows
)

# Customize the plot
plt.title('Advanced Heatmap of PUC_INSTITUTE Counts Across Years', fontsize=18)
plt.xlabel('AdminYear', fontsize=14)
plt.ylabel('PUC_INSTITUTE', fontsize=14)
plt.setp(cluster_map.ax_heatmap.xaxis.get_majorticklabels(), fontsize=12)
plt.setp(cluster_map.ax_heatmap.yaxis.get_majorticklabels(), fontsize=12)
plt.show()

# %%
sorted(list(df['PUC_INSTITUTE'].unique()))
# Out:
# ['ABHYUDAYA COLLEGE VIJAYAPUR',
#  'ALVAS PU COLLEGE MOODBIDRI',
#  'ANAND ASHRAM COMPOSITE PU COLLEGE',
#  'ANANDATHIRTHA PU COLLEGE,KUNJARUGIRI',
#  'ARJUNA SCIENCE PU COLLEGE DHARAWAD',
#  'AT PUC PAJAKA KUNJARGIRI',
#  'BGS INDEPENDENT PU GURUPURA',
#  'BHANDARKARS PUE UNIVERSITY COLLEGE KUNDAPURA',
#  'CEOA MATRIC HR SEC SCHOOL MADURAI',
#  'CHANNAKESHWARA PU COLLEGE',
#  'D V S (IND) PU COLLEGE SHIVAMOGGA',
#  'DANDATHIRTHA PU COLLEGE KAUP',
#  'DIPLOMA',
#  'DKG PU COLLEGE KRISHNANAGAR SANDUR',
#  'DR. R.B PATIL MAHESH PU COLLEGE, HUBLI',
#  'DR.NSAM PUC NITTE',
#  'EX PU COLLEGE KUNDAPUR',
#  'EXCELLENT PU COLLEGE SUNNAR KOTESHWARA',
#  'EXCELLENT PU COLLEGE SUNNARI',
#  'G I P U COLLEGE BAAD',
#  'G P T UDUPI',
#  'G P U C BAILUR',
#  'G P U C HIRIADKA',
#  'G P U COLLEGE BELMAN',
#  'G P U COLLEGE HIRIADKA',
#  'G.P.C HIRIADKA',
#  'GIRLS COLLEGE UDUPI',
#  'GNANA GANAGA COLLGE',
#  'GOT COLLEGE HIRIADKA',
#  'GOVERNMENT PU COLLEGE, BAROOR',
# ...

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [ 
      'SRI VAIKUNTARAMANA PREUNIVERSITY \xa0COLLEGE KUNDAPUR'
],
    'SRI VAIKUNTARAMANA PREUNIVERSITY COLLEGE KUNDAPUR'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [ 
      'ST.MARYS SYRIAN PU COLLEGE BRAHMAVARA',
 'ST.MARYS SYRIAN PUC BRAHMAVARA',
],
    'ST MARYS PU COLLEGE BRAHMAVARA'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [ 
      'ST. MARYS PU COLLEGE KUNDAPURA','ST MARRY"S PU KUNDAPURA',
],
    'ST MARYS PU COLLEGE KUNDAPURA'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [ 
      'ST. MARYS PU COLLEGE KUNDAPURA','ST MARRY"S PU KUNDAPURA',
],
    'ST MARYS PU COLLEGE KUNDAPURA'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [ 
      'ST MARRY`S SHIRVA',
 'ST MARYS PU COLLEGE SHIRVA',
 'ST.MARYS PU COLLEGE SHIRVA',
 'ST.MARYS SHIRVA',
 'ST MARYS SHIRVA',
],
    'ST MARYS PU COLLEGE SHIRVA'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [ 'ST LAWRENCE MOODUBELLE',
 'ST LAWRENCE PU MUDUBELLE',
 'ST. LAWRENCE, MOODUBELLE',
 'ST.LAWRANCE PU MOODUBELLE',
 'ST.LAWRENCE MUDUBELLE',
 'ST.LAWRENCE PU COLLEGE',
 'ST.LAWRENCE PU COLLEGE MOODUBELLE',
],
    'ST LAWRENCE PU MUDUBELLE',
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['SRI BHUVANENDRA COLLEGE',
 'SRI BHUVANENDRA PU COLLEGE KARKALA',
 
],
    'SRI BHUVANENDRA PU COLLEGE KARKALA'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['SAHMILI PU COLLEGE',
     'SHAMILI PRE UNIVERSITY COLLEGE KIDIYOOR',
 'SHAMILI PRE.UNIVERSITY COLLEGE KIDIYOOR',
 'SHAMILI PU COLLEGE',
 'SHAMILI PU COLLEGE KIDIYOOR',
 'SHAMILI PU COLLEGE KIDIYOOR, UDUPI',
 'SHAMILI PU COLLEGE KIDIYUR',
 'SHAMILI PU COLLEGE UDUPI',
 'SHAMILI PU COLLEGE,KIDIYOOR',
 'SHAMILI PU KIDIYOOR',
 'SHAMILI PUC KIDIYOOR',
 'SHYAMILI INDD PUC UDUPI',
 'SHYAMILI INDP PU COLLEGE,KIDIYUR',
 
 
],
    'SHAMILI PRE UNIVERSITY COLLEGE KIDIYOOR'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['SAHYADRI PU COLLEGE',
 'SAHYADRI PU COLLEGE YADGIRI',
 
],
    'SAHYADRI PU COLLEGE YADGIRI'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['RN SHETTY PU COLLEGE KUNDAPURA',
 'RNS COMPOSITE PU COLLEGE, KUNDAPUR',
 'RNS PC KUNDAPURA',
 'RNS PU COLLEGE',
 'RNS, KUNDAPURA',
],
    'RN SHETTY PU COLLEGE KUNDAPURA',
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['POORNAPRAJNA COLLEGE,ADMAR',
 'POORNAPRAJNA PU COLLEGE ADMAR',
 'PPC ADAMAR',
 'PPC ADMAR',
 'POORNAPRAJNA, ADMAR',
 
],
    'POORNAPRAJNA PU COLLEGE ADMAR'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [ 'MOTHER TERESAS PU COLLEGE SHANKARNARAYAN KUNDAPUR',
 'MOTHER TERESSA PU',
],
     'MOTHER TERESAS PU COLLEGE SHANKARNARAYAN KUNDAPUR'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['MKS MANIPAL',
 'MKS,MANIPAL',
],
    'MKS MANIPAL',
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['MILAGRES KALLIYANPURA',
 'MILAGRES PU COLLEGE KALLIANPUR',
 'MILAGRES PU COLLLEGE',
 'MILLAGRES KALLIANPURA',
],
     'MILAGRES PU COLLEGE KALLIANPUR'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [ 'MAHESH PU COLLEGE, UDUPI',
 'MAHESH PU COLLOEGE UDUPI',
 'MAHESH PU',
],
 'MAHESH PU COLLOEGE UDUPI',
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [ 'PPC UDUIP',
      'P.P.C',
 'PPC UDUPI',
 'PPC \xa0UDUPI',
 'PPC \xa0\xa0PU COLLEGE',
 'PPC,UDUPI',
  'PPC',
  'POORNAPRAJNA PU COLLEGE UDUPI',
 'POORNAPRAJNA PU COLLEGE,UDUPI',
],
    'POORNAPRAJNA PU COLLEGE UDUPI'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['M G M , UDUPI',
 'M G M COLLEGE',
 'M G M COLLEGE UDUPI',
 'M G M KUNJIBETTU',
 'M G M PU COLLEGE',
 'M G M UDUPI',
 'MAHATMA GANDHI COLLEGE',
 'MAHATMA GANDHI MEMO.PU COLLEGE,UDUPI',
 'MGM',
 'MGM COLLEGE UDUPI',
 'MGM PU COLLEGE KUNJIBETTU UDUPI',
 'MGM PU COLLEGE UDUPI',
 'MGM PU COLLEGE UDUPI ',
 'MGM PU UDUPI',
 'MGM UDUPI',
 'M.G.M',
],
    'M G M COLLEGE UDUPI'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['LITTLE ROCK INDIAN SCHOOL',
 'LRIS BRAHMAVAR',
],
    'LITTLE ROCK INDIAN SCHOOL'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [ 'JNANAGANGA PU COLLAGE',
 'JNANAGANGA PU COLLEGE',
 'JNANAGANGA PU COLLEGE NELLIKATTE',
 'JNANAGANGA PU COLLEGE NELLIKATTE UDUPI',
 'JNANAGANGA PU COLLEGE NELLIKATTE,MOODUBELLE',
 'JNANAGANGA PU NELLIKATTE',
 'JPC NELLIKATTE UDUPI',
],
   'JNANAGANGA PU COLLEGE NELLIKATTE'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['H.P.U.C SHIRVA','HINDU P U COLLEGE, SHIRVA',
 'HINDU PRE UNIVERSITY COLLEGE SHIRVA',
 'HINDU PU COLLEGE SHIRVA',
 'HINDU PU COLLEGE,SHIRVA',
],
    'HINDU PRE UNIVERSITY COLLEGE SHIRVA'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['GOVT PU COLLEGE BRAHMAVARA','GOVT PU COLLGE, BRAHMAVAR','GOVT.PU COLLEGE BRAHMAVAR','GOVT.PU COLLEGE BRAHMAVARA','GPUC BRAHMAVAR',],
    'GOVT PU COLLEGE BRAHMAVARA'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['GOVT PU COLLAGE UDUPI','GOVT PU COLLEGE UDUPI'],
    'GOVT PU COLLEGE UDUPI'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['DANDATHIRTHA P U COLLEGE ULIYARAGOLI KAUP',
 'DANDATHIRTHA PU COLLEGE',
 'DANDATHIRTHA PU COLLEGE KAUP',
 'DANDATHIRTHA PU COLLEGE,KAUP',],
    'DANDATHIRTHA PU COLLEGE KAUP'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['DANDATHIRTHA P U COLLEGE ULIYARAGOLI KAUP',
 'DANDATHIRTHA PU COLLEGE',
 'DANDATHIRTHA PU COLLEGE KAUP',
 'DANDATHIRTHA PU COLLEGE,KAUP',],
    'DANDATHIRTHA PU COLLEGE KAUP'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['BHANDARKARS PU COLLEGE,KUNDAPURA',
 'BHANDARKARS PUE UNIVERSITY COLLEGE KUNDAPURA',],
    'BHANDARKARS PUE UNIVERSITY COLLEGE KUNDAPURA'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['ANANDATHIRTHA',
 'ANANDATHIRTHA PU COLLEGE,KUNJARUGIRI',],
    'ANANDATHIRTHA PU COLLEGE,KUNJARUGIRI'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['ALVAS MOODABIDRI', 'ALVAS PU COLLEGE MOODBIDRI', 'ALVAS PUC MOODUBIDRE'],
    'ALVAS PU COLLEGE MOODBIDRI'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['ANAND ASHRAM COMPOSITE PU COLLEGE',
 'ANAND ASHRAM PU COLLEGE',
 'ANANDA ASHRAM'],
    'ANAND ASHRAM COMPOSITE PU COLLEGE'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [ 'VIVEK KOTA',
 'VIVEK PU COLLEGE BRAHMAVAR',
 'VIVEK PU COLLEGE KOTA',
 'VIVEKA PRE-UNIVERSITY',
 'VIVEKA PU COLLAGE KOTA',
 'VIVEKA PU COLLEGE',
 'VIVEKA PU KOTA',
 'VIVEKANANDA PU COLLEGE',
 'VIC \xa0KOTA',
 'KOTA VIVEKA PRE UNI COLLEGE',
 'Y J R'],
    'VIVEK PU COLLEGE KOTA'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [ 'VIDYDAYA UDUPI',
 'VIDYODAYA',
 'VIDYODAYA ,UDUPI',
 'VIDYODAYA PU COLLEGE',
 'VIDYODAYA PU COLLEGE UDUPI',
 'VIDYODAYA PU UDUOI',
 'VIDYODAYA PUC,UDUPI',
 'VIDYODAYA UDUPI',
 'VIDYODHAYA PU',
  'VIDHYODAYA PU COLLEGE UDUPI',
 'VIDYADAYA UDUPI',],
    'VIDYODAYA PU COLLEGE UDUPI'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    ['SMS COLLEGE BRAHMAVAR',
 'SMS PU COLLEGE',
 'SMS PU COLLEGE BRAHMAVAR',
 'SMS PU COLLEGE BRAHMAVARA',
 'SMS PU COLLEGE, BRAHMAVARA',
 'SMS PUC BRAHMAVAR',],
    'SMS PU COLLEGE BRAHMAVAR'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [  'VIDYANEKETAN PU COLLEGE',
 'VIDYANIKETAN P U COLLEGE , KAUP',],
    'VIDYANEKETAN PU COLLEGE'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [  'VENKATARAMANA KUNDAPURA',
      'SRI VENKATARAMANA ENG SCHOOL KUNDAPURA',
 'SRI VENKATARAMANA PU COLLEGE KUNDAPURA',
 'VENKATARAMANA PU COLLEGE KUNDAPURA',],
    'VENKATARAMANA PU COLLEGE KUNDAPURA'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [  'VENKATARAMANA KUNDAPURA',
 'VENKATARAMANA PU COLLEGE KUNDAPURA',],
    'VENKATARAMANA PU COLLEGE KUNDAPURA'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [ 'VARASIDDHI VINAYAKA PU COLLEGE,KERADI',
 'VARASIDDHIVINAYAKA PU COLLEGE KERADI',
 'VARASIDDIVINAYAKA PU COLLEGE KERADI',],
    'VARASIDDHIVINAYAKA PU COLLEGE KERADI'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [  'SVH INNANJE',
 'SVH PU COLLEGE',
 'SVH PU COLLEGE INNANJE',
 'SVH PU COLLEGE \xa0INNANJE',
 'SVH PU COLLEGE,INNANJE',
 'SVH PU INNANJE',
 'SVH PUC INNANJE',
 'SVH PUC,INNANJE', 'S.V.H PU INNANJE',
  'S.V.H. PU COLLEGE INNANJE',
  'S V H PU COLLEGE,INNANJE',
 'SVPU',],
    'SVH PU COLLEGE INNANJE'
)

# %%
df['PUC_INSTITUTE'] = df['PUC_INSTITUTE'].replace(
    [ 'VARASIDDHI VINAYAKA PU COLLEGE,KERADI',
 'VARASIDDHIVINAYAKA PU COLLEGE KERADI',
 'VARASIDDIVINAYAKA PU COLLEGE KERADI',],
    'VARASIDDHIVINAYAKA PU COLLEGE KERADI'
)

# %%
len(list(df['PUC_INSTITUTE'].unique()))
# Out:
# 186

# %%
df.to_csv("final_data.csv",index=False)
